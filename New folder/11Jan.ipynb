# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('Cleaned-2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title Salary Estimate  \
# 0           0             Data Scientist       $53K-$91K
# 1           1  Healthcare Data Scientist      $63K-$112K
# 2           2             Data Scientist       $80K-$90K
# 3           3             Data Scientist       $56K-$97K
# 4           4             Data Scientist      $86K-$143K
#
#                                      Job Description  Rating    Headquarters  \
# 0  ['Data Scientist', 'Location: Albuquerque, NM'...     3.8      Goleta, CA
# 1  ['What You Will Do:', '', 'I. General Summary'...     3.4   Baltimore, MD
# 2  ["KnowBe4, Inc. is a high growth information s...     4.8  Clearwater, FL
# 3  ['*Organization and Job ID**', 'Job ID: 310709...     3.8    Richland, WA
# 4  ['Data Scientist', 'Affinity Solutions / Marke...     2.9    New York, NY
#
#    Size  Founded   Type of ownership                          Industry  ...  \
# 0     4     1973   Company - Private               Aerospace & Defense  ...
# ...

# %%
df['Salary Estimate'].unique()
# Out:
# array(['$53K-$91K', '$63K-$112K', '$80K-$90K', '$56K-$97K', '$86K-$143K',
#        '$71K-$119K', '$54K-$93K', '$86K-$142K', '$38K-$84K',
#        '$120K-$160K', '$126K-$201K', '$64K-$106K', '$106K-$172K',
#        '$46K-$85K', '$83K-$144K', '$102K-$190K', '$67K-$137K',
#        '$118K-$189K', '$110K-$175K', '$64K-$111K', '$81K-$130K',
#        '$73K-$119K', '$86K-$139K', '$63K-$105K', '$109K-$177K',
#        '$63K-$110K', '$75K-$124K', '$34K-$61K', '$72K-$120K',
#        '$93K-$149K', '$85K-$140K', '$77K-$135K', '$82K-$132K',
#        '$83K-$137K', '$115K-$180K', '$74K-$138K', '$64K-$112K',
#        '$68K-$129K', '$52K-$113K', '$110K-$150K', '$150K-$160K',
#        '$158K-$211K', '$20K-$39K', '$56K-$117K', '$63K-$99K',
#        '$68K-$114K', '$41K-$95K', '$86K-$144K', '$80K-$139K', '$56K-$95K',
#        '$120K-$189K', '$111K-$176K', '$84K-$146K', '$107K-$172K',
#        '$49K-$85K', '$61K-$109K', '$88K-$148K', '$60K-$99K', '$41K-$72K',
# ...

# %%
df['Company Name'].unique()
# Out:
# array(['Tecolote Research', 'University of Maryland Medical System',
#        'KnowBe4', 'PNNL', 'Affinity Solutions', 'CyrusOne',
#        'ClearOne Advantage', 'Logic20/20', 'Rochester Regional Health',
#        '<intent>', 'Wish', 'ManTech', 'Walmart', 'Yesler',
#        'Takeda Pharmaceuticals', 'Audible', 'Blueprint Medicines',
#        'h2o.ai', 'Nuna', 'Pinnacol Assurance', 'Porch', 'Health IQ',
#        'Truckstop.com', 'SMC 3', 'Novetta', 'Pfizer',
#        'First Tech Federal Credit Union', 'The Hanover Insurance Group',
#        'Amrock', 'Novartis', 'Juniper Networks', 'New England Biolabs',
#        'Clarity Insights', 'Esri', 'Systems & Technology Research',
#        'Sartorius', 'Lancer Insurance', 'Sauce Labs', 'Persivia',
#        'Edgewell Personal Care', 'Equity Residential', 'BPA Services',
#        'Visa Inc.', 'Intrado', 'Centauri', 'Caterpillar',
#        'Zimmerman Advertising', 'Liberty Mutual Insurance',
# ...

# %%
df.drop(columns='seniority',inplace=True)

# %%
df.drop(columns='employer_provided',inplace=True)

# %%
df['Job Description'][0]
# Out:
# "['Data Scientist', 'Location: Albuquerque, NM', 'Education Required: Bachelor’s degree required, preferably in math, engineering, business, or the sciences.', 'Skills Required:', 'Bachelor’s Degree in relevant field, e.g., math, data analysis, database, computer science, Artificial Intelligence (AI); three years’ experience credit for Master’s degree; five years’ experience credit for a Ph.D', 'Applicant should be proficient in the use of Power BI, Tableau, Python, MATLAB, Microsoft Word, PowerPoint, Excel, and working knowledge of MS Access, LMS, SAS, data visualization tools, and have a strong algorithmic aptitude', 'Excellent verbal and written communication skills, and quantitative analytical skills are required', 'Applicant must be able to work in a team environment', 'U.S. citizenship and ability to obtain a DoD Secret Clearance required', 'Responsibilities: The applicant will be responsible for formulating analytical solutions to complex data problems; creating data analytic 
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                           0
# Job Title                                               Data Scientist
# Salary Estimate                                              $53K-$91K
# Job Description      ['Data Scientist', 'Location: Albuquerque, NM'...
# Rating                                                             3.8
# Headquarters                                                Goleta, CA
# Size                                                                 4
# Founded                                                           1973
# Type of ownership                                    Company - Private
# Industry                                           Aerospace & Defense
# Sector                                             Aerospace & Defense
# Revenue                                      $50 to $100 million (USD)
# Competitors                                                       None
# ...

# %%
num=0
for i in df['Salary Estimate']:
    if ' Per Hour' in i:
        print('Dropped: ',num)
        df.drop(num,inplace=True)
    num+=1
# Out:
# Dropped:  165
# Dropped:  177
# Dropped:  197
# Dropped:  202
# Dropped:  210
# Dropped:  246
# Dropped:  271
# Dropped:  337
# Dropped:  345
# Dropped:  357
# Dropped:  363
# Dropped:  408
# Dropped:  409
# Dropped:  492
# Dropped:  509
# Dropped:  533
# Dropped:  542
# Dropped:  615
# Dropped:  616
# Dropped:  643
# Dropped:  664
# Dropped:  680
# Dropped:  709
# Dropped:  722

# %%
df['Salary Estimate'][157]
# Out:
# '$52K-$101K'

# %%
df['Salary Estimate'].unique()
# Out:
# array(['53000-91000', '63000-112000', '80000-90000', '56000-97000',
#        '86000-143000', '71000-119000', '54000-93000', '86000-142000',
#        '38000-84000', '120000-160000', '126000-201000', '64000-106000',
#        '106000-172000', '46000-85000', '83000-144000', '102000-190000',
#        '67000-137000', '118000-189000', '110000-175000', '64000-111000',
#        '81000-130000', '73000-119000', '86000-139000', '63000-105000',
#        '109000-177000', '63000-110000', '75000-124000', '34000-61000',
#        '72000-120000', '93000-149000', '85000-140000', '77000-135000',
#        '82000-132000', '83000-137000', '115000-180000', '74000-138000',
#        '64000-112000', '68000-129000', '52000-113000', '110000-150000',
#        '150000-160000', '158000-211000', '20000-39000', '56000-117000',
#        '63000-99000', '68000-114000', '41000-95000', '86000-144000',
#        '80000-139000', '56000-95000', '120000-189000', '111000-176000',
# ...

# %%
df.reset_index(inplace=True)

# %%
df['Salary Estimate'][165]
# Out:
# '$91K-$149K'

# %%
num=0
for i in df['Salary Estimate']:
    print(type(i))
    df['Salary Estimate'][num]=str(i).replace('K','000')
    num+=1
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
df['Sal Est']=None

# %%
'$78K-$147K'.replace('K','000')
# Out:
# '$78000-$147000'

# %%
df['Sal Est']
# Out:
# 0        [$53K, $91K]
# 1       [$63K, $112K]
# 2        [$80K, $90K]
# 3        [$56K, $97K]
# 4       [$86K, $143K]
#             ...
# 712     [$72K, $133K]
# 713      [$56K, $91K]
# 714     [$95K, $160K]
# 715     [$61K, $126K]
# 716    [$61K, $126K ]
# Name: Sal Est, Length: 717, dtype: object

# %%
type(df['Sal Est'][0][0])
# Out:
# str

# %%
df
# Out:
#      index  Unnamed: 0                                          Job Title  \
# 0        0           0                                     Data Scientist
# 1        1           1                          Healthcare Data Scientist
# 2        2           2                                     Data Scientist
# 3        3           3                                     Data Scientist
# 4        4           4                                     Data Scientist
# ..     ...         ...                                                ...
# 712    736         736           Sr Scientist, Immuno-Oncology - Oncology
# 713    737         737                               Senior Data Engineer
# 714    738         738  Project Scientist - Auton Lab, Robotics Institute
# 715    739         739                               Data Science Manager
# 716    740         740          Research Scientist – Security and Privacy
#
#     Salary Estimate                                    Job Description  \
# ...

# %%
def average(s):
    avg=s.split('-')
    avg = list(map(int,avg))
    avg=np.mean(avg)
#     print(avg)
    return avg

# %%
num=0
for i in df['Salary Estimate']:
    df['Salary Estimate'][num]=average(df['Salary Estimate'][num])
    num+=1
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_21624\2109042608.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary Estimate'][num]=average(df['Salary Estimate'][num])

# %%
df['Salary Estimate']=df['Salary Estimate'].astype(int)

# %%
df
# Out:
#      index  Unnamed: 0                                          Job Title  \
# 0        0           0                                     Data Scientist
# 1        1           1                          Healthcare Data Scientist
# 2        2           2                                     Data Scientist
# 3        3           3                                     Data Scientist
# 4        4           4                                     Data Scientist
# ..     ...         ...                                                ...
# 712    736         736           Sr Scientist, Immuno-Oncology - Oncology
# 713    737         737                               Senior Data Engineer
# 714    738         738  Project Scientist - Auton Lab, Robotics Institute
# 715    739         739                               Data Science Manager
# 716    740         740          Research Scientist – Security and Privacy
#
#      Salary Estimate                                    Job Description  \
# ...

# %%
df.to_csv('Cleaned-3.csv')

# %%
if np.nan in df['Company Name'].unique():
    print(True)
