# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot
# %matplotlib inline

# %%
data = pd.read_csv('Cleaned-1.csv')

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data.drop(['CompanyName'],axis=1,inplace=True)

# %%
data.drop(['Salary_Estimate'],axis=1,inplace=True)

# %%
data
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 736           Sr Scientist, Immuno-Oncology - Oncology
# 737                               Senior Data Engineer
# 738  Project Scientist - Auton Lab, Robotics Institute
# 739                               Data Science Manager
# 740          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0                      $53K-$91K
# 1                     $63K-$112K
# 2                      $80K-$90K
# 3                      $56K-$97K
# 4                     $86K-$143K
# ..                           ...
# 736                   $72K-$133K
# ...

# %%
def func():
    num=0
    for i in data['Job Description']:
        data['JD'][num]=data['Job Description'][num].split('\n')
        num+=1

# %%
data['JD']=data['Job Description']

# %%
func()
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_26536\3774654965.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['JD'][num]=data['Job Description'][num].split('\n')

# %%
data['JD']
# Out:
# 0      [Data Scientist, Location: Albuquerque, NM, Ed...
# 1      [What You Will Do:, , I. General Summary, , Th...
# 2      [KnowBe4, Inc. is a high growth information se...
# 3      [*Organization and Job ID**, Job ID: 310709, ,...
# 4      [Data Scientist, Affinity Solutions / Marketin...
#                              ...
# 736    [Site Name: USA - Massachusetts - Cambridge, P...
# 737    [THE CHALLENGE, Eventbrite has a world-class d...
# 738    [The Auton Lab at Carnegie Mellon University i...
# 739    [Data Science ManagerResponsibilities:, , Over...
# 740    [Returning Candidate? Log back in to the Caree...
# Name: JD, Length: 741, dtype: object

# %%
data['Salary_Estimate']=data['Salary Estimate']

# %%
data
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 736           Sr Scientist, Immuno-Oncology - Oncology
# 737                               Senior Data Engineer
# 738  Project Scientist - Auton Lab, Robotics Institute
# 739                               Data Science Manager
# 740          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0                      $53K-$91K
# 1                     $63K-$112K
# 2                      $80K-$90K
# 3                      $56K-$97K
# 4                     $86K-$143K
# ..                           ...
# 736                   $72K-$133K
# ...

# %%
data['Salary Estimate'].unique()
# Out:
# array(['$53K-$91K', '$63K-$112K', '$80K-$90K', '$56K-$97K', '$86K-$143K',
#        '$71K-$119K', '$54K-$93K', '$86K-$142K', '$38K-$84K',
#        '$120K-$160K', '$126K-$201K', '$64K-$106K', '$106K-$172K',
#        '$46K-$85K', '$83K-$144K', '$102K-$190K', '$67K-$137K',
#        '$118K-$189K', '$110K-$175K', '$64K-$111K', '$81K-$130K',
#        '$73K-$119K', '$86K-$139K', '$63K-$105K', '$109K-$177K',
#        '$63K-$110K', '$75K-$124K', '$34K-$61K', '$72K-$120K',
#        '$93K-$149K', '$85K-$140K', '$77K-$135K', '$82K-$132K',
#        '$83K-$137K', '$115K-$180K', '$74K-$138K', '$64K-$112K',
#        '$68K-$129K', '$52K-$113K', '$110K-$150K',
#        'Employer Provided Salary:$150K-$160K', '$158K-$211K', '$20K-$39K',
#        '$56K-$117K', '$63K-$99K', '$68K-$114K', '$41K-$95K', '$86K-$144K',
#        '$80K-$139K', '$56K-$95K', '$120K-$189K', '$111K-$176K',
#        '$84K-$146K', '$107K-$172K', '$49K-$85K', '$61K-$109K',
# ...

# %%
num=0
for i in data['Salary Estimate']:
    data['Salary Estimate'][num]=i.replace('Employer Provided Salary:','')
    num+=1
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_26536\1688625084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Salary Estimate'][num]=i.replace('Employer Provided Salary:','')

# %%
'Employer Provided Salary:$150K-$160K'.replace('Employer Provided Salary:','')
# Out:
# '$150K-$160K'

# %%
for i in data['Salary Estimate']:
    print(i)
# Out:
# $53K-$91K
# $63K-$112K
# $80K-$90K
# $56K-$97K
# $86K-$143K
# $71K-$119K
# $54K-$93K
# $86K-$142K
# $38K-$84K
# $120K-$160K
# $126K-$201K
# $64K-$106K
# $106K-$172K
# $46K-$85K
# $83K-$144K
# $102K-$190K
# $67K-$137K
# $118K-$189K
# $110K-$175K
# $64K-$111K
# $81K-$130K
# $73K-$119K
# $86K-$139K
# $63K-$105K
# $109K-$177K
# $63K-$110K
# $75K-$124K
# $34K-$61K
# $63K-$105K
# $80K-$90K
# $56K-$97K
# $72K-$120K
# $86K-$143K
# $93K-$149K
# $85K-$140K
# $77K-$135K
# $82K-$132K
# $83K-$137K
# $115K-$180K
# $74K-$138K
# $64K-$112K
# $68K-$129K
# $110K-$175K
# $52K-$113K
# $110K-$150K
# $150K-$160K
# $158K-$211K
# $20K-$39K
# $56K-$117K
# $63K-$99K
# $68K-$114K
# $86K-$143K
# $41K-$95K
# $86K-$144K
# $80K-$139K
# $56K-$95K
# $120K-$189K
# $111K-$176K
# $54K-$93K
# $71K-$119K
# $82K-$132K
# $84K-$146K
# $107K-$172K
# $49K-$85K
# $61K-$109K
# $88K-$148K
# $60K-$99K
# $41K-$72K
# $96K-$161K
# $65K-$130K
# $52K-$81K
# $139K-$220K
# $50K-$102K
# $85K-$139K
# $74K-$122K
# $99K-$157K
# $79K-$222K
# ...

# %%
num=0
for i in data['Salary Estimate']:
    data['Salary Estimate'][num]=i.replace('(Glassdoor est.)','')
    num+=1
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_26536\2781162198.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Salary Estimate'][num]=i.replace('(Glassdoor est.)','')

# %%
data
# Out:
#                                              Job Title Salary Estimate  \
# 0                                       Data Scientist       $53K-$91K
# 1                            Healthcare Data Scientist      $63K-$112K
# 2                                       Data Scientist       $80K-$90K
# 3                                       Data Scientist       $56K-$97K
# 4                                       Data Scientist      $86K-$143K
# ..                                                 ...             ...
# 736           Sr Scientist, Immuno-Oncology - Oncology      $72K-$133K
# 737                               Senior Data Engineer       $56K-$91K
# 738  Project Scientist - Auton Lab, Robotics Institute      $95K-$160K
# 739                               Data Science Manager      $61K-$126K
# 740          Research Scientist – Security and Privacy     $61K-$126K
#
#                                        Job Description  Rating  \
# ...

# %%
data['Job Description']=data['JD']

# %%
data['Job Title']
# Out:
# 0                                         Data Scientist
# 1                              Healthcare Data Scientist
# 2                                         Data Scientist
# 3                                         Data Scientist
# 4                                         Data Scientist
#                              ...
# 736             Sr Scientist, Immuno-Oncology - Oncology
# 737                                 Senior Data Engineer
# 738    Project Scientist - Auton Lab, Robotics Institute
# 739                                 Data Science Manager
# 740            Research Scientist – Security and Privacy
# Name: Job Title, Length: 741, dtype: object

# %%
data['Job Description'][54]
# Out:
# ["At Northrop Grumman we develop cutting-edge technology that preserves freedom and advances human discovery. Our pioneering and inventive spirit has enabled us to be at the forefront of many technological advancements in our nation's history - from the first flight across the Atlantic Ocean, to stealth bombers, to landing on the moon. We continue to innovate with developments from launching the first commercial flight to space, to discovering the early beginnings of the universe. Our employees are not only part of history, they're making history.",
#  '',
#  'The Engineering & Sciences (E&S) organization pushes the boundaries of innovation, redefines engineering capabilities, and drives advances in various sciences. Our team is chartered with providing the skills, innovative technologies to develop, design, produce and sustain optimized product lines across the sector while providing a decisive advantage to the warfighter. Come be a part of our mission!',
#  '',
# ...

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'employer_provided', 'min_salary',
#        'max_salary', 'avg_salary', 'company_txt', 'age', 'job_simp',
#        'seniority', 'skills', 'Company Rating', 'Company Name'],
#       dtype='object')

# %%
data.drop(['JD'],axis=1,inplace=True)

# %%
data[['company_txt','Company Name']]
# Out:
#                                company_txt       Company Name
# 0                        Tecolote Research  Tecolote Research
# 1    University of Maryland Medical System  Tecolote Research
# 2                                  KnowBe4  Tecolote Research
# 3                                     PNNL  Tecolote Research
# 4                       Affinity Solutions  Tecolote Research
# ..                                     ...                ...
# 736                                    GSK  Tecolote Research
# 737                             Eventbrite  Tecolote Research
# 738         Software Engineering Institute  Tecolote Research
# 739                           Numeric, LLC  Tecolote Research
# 740           Riverside Research Institute                NaN
#
# [741 rows x 2 columns]

# %%
data.drop(['hourly'],axis=1,inplace=True)

# %%
df = pd.read_csv('eda_data.csv')

# %%
df['Company Name']
# Out:
# 0                          Tecolote Research\n3.8
# 1      University of Maryland Medical System\n3.4
# 2                                    KnowBe4\n4.8
# 3                                       PNNL\n3.8
# 4                         Affinity Solutions\n2.9
#                           ...
# 737                                      GSK\n3.9
# 738                               Eventbrite\n4.4
# 739           Software Engineering Institute\n2.6
# 740                             Numeric, LLC\n3.2
# 741             Riverside Research Institute\n3.6
# Name: Company Name, Length: 742, dtype: object

# %%
def why():
    num=0
    for i in df['Company Name']:
        if (len(df['Company Name'][num].split('\n'))==2):
            data['Company Name'][num], data['Company Rating'][num] = df['Company Name'][num].split('\n')
        else (len(df['Company Name'][num].split('\n'))==1):
            data['Company Name'][num] = df['Company Name'][num].split('\n')[0]
        num+=1
# Out:
#   File "C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_26536\1598369438.py", line 6
#     else (len(df['Company Name'][num].split('\n'))==1):
#          ^
# SyntaxError: invalid syntax

# %%
len(df['Company Name'][num].split('\n'))==2

# %%
df['Company Name']
# Out:
# 0                          Tecolote Research\n3.8
# 1      University of Maryland Medical System\n3.4
# 2                                    KnowBe4\n4.8
# 3                                       PNNL\n3.8
# 4                         Affinity Solutions\n2.9
#                           ...
# 737                                      GSK\n3.9
# 738                               Eventbrite\n4.4
# 739           Software Engineering Institute\n2.6
# 740                             Numeric, LLC\n3.2
# 741             Riverside Research Institute\n3.6
# Name: Company Name, Length: 742, dtype: object

# %%
why()
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_26536\2227677972.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Company Name'][num],data['Company Rating'][num]=df['Company Name'][num].split('\n')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26536\2331865685.py in <module>
# ----> 1 why()
#
# ~\AppData\Local\Temp\ipykernel_26536\2227677972.py in why()
#       2     num=0
#       3     for i in df['Company Name']:
# ----> 4         data['Company Name'][num],data['Company Rating'][num]=df['Company Name'][num].split('\n')
#       5         num+=1
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
data
# Out:
#                                              Job Title Salary Estimate  \
# 0                                       Data Scientist       $53K-$91K
# 1                            Healthcare Data Scientist      $63K-$112K
# 2                                       Data Scientist       $80K-$90K
# 3                                       Data Scientist       $56K-$97K
# 4                                       Data Scientist      $86K-$143K
# ..                                                 ...             ...
# 736           Sr Scientist, Immuno-Oncology - Oncology      $72K-$133K
# 737                               Senior Data Engineer       $56K-$91K
# 738  Project Scientist - Auton Lab, Robotics Institute      $95K-$160K
# 739                               Data Science Manager      $61K-$126K
# 740          Research Scientist – Security and Privacy     $61K-$126K
#
#                                        Job Description  Rating  \
# ...

# %%
data.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'employer_provided', 'min_salary',
#        'max_salary', 'avg_salary', 'company_txt', 'age', 'job_simp',
#        'seniority', 'skills', 'Company Rating', 'Company Name'],
#       dtype='object')

# %%
data[['Company Name','Company Rating','company_txt']]
# Out:
#                               Company Name Company Rating  \
# 0                        Tecolote Research            3.8
# 1    University of Maryland Medical System            3.4
# 2                                  KnowBe4            4.8
# 3                                     PNNL            3.8
# 4                       Affinity Solutions            2.9
# ..                                     ...            ...
# 736                      Tecolote Research            3.8
# 737                      Tecolote Research            3.8
# 738                      Tecolote Research            3.8
# 739                      Tecolote Research            3.8
# 740                                    NaN            NaN
#
#                                company_txt
# 0                        Tecolote Research
# 1    University of Maryland Medical System
# 2                                  KnowBe4
# 3                                     PNNL
# 4                       Affinity Solutions
# ...

# %%
data.iloc[144]
# Out:
# Job Title                              Data Scientist - Bioinformatics
# Salary Estimate                                              $49K-$85K
# Job Description      [*Organization and Job ID**, Job ID: 310433, ,...
# Rating                                                             3.8
# Headquarters                                              Richland, WA
# Size                                                                 5
# Founded                                                           1965
# Type of ownership                                           Government
# Industry                                                        Energy
# Sector                                    Oil, Gas, Energy & Utilities
# Revenue                               $500 million to $1 billion (USD)
# Competitors          Oak Ridge National Laboratory, National Renewa...
# employer_provided                                                    0
# ...

# %%
df.iloc[736]
# Out:
# Unnamed: 0                                                         736
# Job Title                 Principal, Data Science - Advanced Analytics
# Salary Estimate                            $86K-$137K (Glassdoor est.)
# Job Description      IQVIA is the leading human data science compan...
# Rating                                                             3.6
# Company Name                                                IQVIA\n3.6
# Location                                          Plymouth Meeting, PA
# Headquarters                                                Durham, NC
# Size                                                  10000+ employees
# Founded                                                           2017
# Type of ownership                                     Company - Public
# Industry                                     Biotech & Pharmaceuticals
# Sector                                       Biotech & Pharmaceuticals
# ...

# %%
L = []
num=0
for i in df['Company Name'].unique():
    if '\n' not in i:
        print(i,num)
    num+=1
#         print(i)
# Out:
# CA-One Tech Cloud 144
# Muso 206
# Kronos Bio 234
# ALIN 278
# Monte Rosa Therapeutics 315

# %%
df['Company Name'].unique()
# Out:
# array(['Tecolote Research\n3.8',
#        'University of Maryland Medical System\n3.4', 'KnowBe4\n4.8',
#        'PNNL\n3.8', 'Affinity Solutions\n2.9', 'CyrusOne\n3.4',
#        'ClearOne Advantage\n4.1', 'Logic20/20\n3.8',
#        'Rochester Regional Health\n3.3', '<intent>\n4.6', 'Wish\n3.5',
#        'ManTech\n4.1', 'Walmart\n3.2', 'Yesler\n4.1',
#        'Takeda Pharmaceuticals\n3.7', 'Audible\n3.6',
#        'Blueprint Medicines\n3.9', 'h2o.ai\n4.3', 'Nuna\n4.2',
#        'Pinnacol Assurance\n4.0', 'Porch\n3.2', 'Health IQ\n3.9',
#        'Truckstop.com\n3.8', 'SMC 3\n4.3', 'Novetta\n4.0', 'Pfizer\n4.0',
#        'First Tech Federal Credit Union\n3.5',
#        'The Hanover Insurance Group\n3.7', 'Amrock\n3.6', 'Novartis\n3.8',
#        'Juniper Networks\n3.8', 'New England Biolabs\n4.7',
#        'Clarity Insights\n4.2', 'Esri\n3.5',
#        'Systems & Technology Research\n4.7', 'Sartorius\n3.5',
#        'Lancer Insurance\n3.5', 'Sauce Labs\n4.2', 'Persivia\n3.6',
# ...

# %%
data.to_csv('Cleaned-2.csv')
