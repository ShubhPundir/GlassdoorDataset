# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Cleaned-3.csv')

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
best250=df.sort_values(by=['Rating'],ascending=False)[:250]

# %%
best250.iloc[249,]
# Out:
# Job Title                                     Principal Data Scientist
# Salary Estimate                                                 161500
# Job Description      ['At AstraZeneca we are constantly pushing the...
# Rating                                                             3.9
# Headquarters                                 Cambridge, United Kingdom
# Size                                                                 7
# Founded                                                           1913
# Type of ownership                                     Company - Public
# Industry                                     Biotech & Pharmaceuticals
# Sector                                       Biotech & Pharmaceuticals
# Revenue                                             $10+ billion (USD)
# Competitors                           Roche, GlaxoSmithKline, Novartis
# company_txt                                                AstraZeneca
# ...

# %%
df.drop(['avg_salary'],axis=1,inplace=True)

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
data=df

# %%
data
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
def func1():
    num=0
    for i in df['Revenue']:
        df['Revenue'][num]=df['Revenue'][num].replace('$','')
        df['Revenue'][num]=df['Revenue'][num].replace('Unknown / Non-Applicable','0')
        df['Revenue'][num]=df['Revenue'][num].replace(' (USD)','')

        num+=1
#         print(i)

# %%
func1()
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\4136982634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'][num]=df['Revenue'][num].replace('$','')
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\4136982634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'][num]=df['Revenue'][num].replace('Unknown / Non-Applicable','0')
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\4136982634.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 million', '2 to 5 billion', '100 to 500 million',
#        '750 million', '0', '1 to 2 billion', '25 to 50 million',
#        '10+ billion', '1 to 5 million', '10 to 25 million',
#        '5 to 10 billion', '50000', '5 to 10 million'], dtype=object)

# %%
def func2():
    num=0
    if 'Less' in df['Revenue'][num]:
        
    num+=1

# %%
L=df[df['Revenue']=='Less than 1 million']['Revenue'].index

# %%
L
# Out:
# Int64Index([436, 439], dtype='int64')

# %%
df['Revenue'].iloc[258,]='50000'
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\3438174836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'].iloc[258,]='50000'

# %%
df['Revenue'].iloc[436,]
# Out:
# '50000'

# %%
for i in L:
    df['Revenue'].iloc[i,]='50000'
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\2312813762.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'].iloc[i,]='50000'

# %%
M2B=df[df['Revenue']=='500 million to 1 billion']['Revenue'].index

# %%
M2B
# Out:
# Int64Index([  3,   8,  19,  30,  31,  63,  79, 121, 133, 144, 149, 158, 180,
#             188, 192, 197, 222, 259, 261, 270, 272, 277, 292, 301, 305, 316,
#             330, 337, 341, 349, 390, 396, 398, 402, 413, 419, 424, 453, 454,
#             476, 502, 508, 519, 545, 581, 587, 596, 601, 604, 620, 622, 630,
#             643, 672, 673, 680, 693],
#            dtype='int64')

# %%
for i in M2B:
    df['Revenue'].iloc[i,]='750 million'
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\3476314541.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'].iloc[i,]='750 million'

# %%
M10=df[df['Revenue']=='10+ billion']['Revenue'].index
for i in M10:
    df['Revenue'].iloc[i,]='10 billion'
# Out:
# C:\Users\Shubh Pundir\AppData\Local\Temp\ipykernel_10244\1468768858.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'].iloc[i,]='10 billion'

# %%
M10=df[df['Revenue']=='10+ billion']['Revenue'].index
for i in M10:
    df['Revenue'].iloc[i,]='10 billion'

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 million', '2 to 5 billion', '100 to 500 million',
#        '750 million', '0', '1 to 2 billion', '25 to 50 million',
#        '10 billion', '1 to 5 million', '10 to 25 million',
#        '5 to 10 billion', '50000', '5 to 10 million'], dtype=object)

# %%
df['temp']=None

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
def fabricate():
    num=0
    for i in df['Revenue']:
        if ' to ' in df['Revenue'][num]:
            df['None'][num]=df['Revenue'][num].split(' to ')
            df['None'].replace('million','')
            df['None'].replace('bllion','')
        num+=1

# %%
fabricate()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'None'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data =df

# %%
data.to_csv('Cleaned-4.csv')
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...
