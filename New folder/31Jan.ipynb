# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Cleaned-4.csv')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 million', '2 to 5 billion', '100 to 500 million',
#        '750 million', '0', '1 to 2 billion', '25 to 50 million',
#        '10 billion', '1 to 5 million', '10 to 25 million',
#        '5 to 10 billion', '50000', '5 to 10 million'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          717 non-null    object
#  1   Salary Estimate    717 non-null    int64
#  2   Job Description    717 non-null    object
#  3   Rating             717 non-null    float64
#  4   Headquarters       717 non-null    object
#  5   Size               717 non-null    int64
#  6   Founded            717 non-null    int64
#  7   Type of ownership  717 non-null    object
#  8   Industry           717 non-null    object
#  9   Sector             717 non-null    object
#  10  Revenue            717 non-null    object
#  11  Competitors        717 non-null    object
#  12  company_txt        717 non-null    object
#  13  age                717 non-null    int64
#  14  job_simp           717 non-null    object
#  15  skills             717 non-null    int64
# ...

# %%
df[df[['Company Rating','Company Name']].isnull().values]
# Out:
#                                      Job Title  Salary Estimate  \
# 716  Research Scientist – Security and Privacy            93500
# 716  Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating   Headquarters  \
# 716  ["Returning Candidate? Log back in to the Care...     3.6  Arlington, VA
# 716  ["Returning Candidate? Log back in to the Care...     3.6  Arlington, VA
#
#      Size  Founded       Type of ownership          Industry      Sector  \
# 716     4     1967  Nonprofit Organization  Federal Agencies  Government
# 716     4     1967  Nonprofit Organization  Federal Agencies  Government
#
#                Revenue Competitors                   company_txt  age  \
# 716  50 to 100 million        None  Riverside Research Institute   53
# 716  50 to 100 million        None  Riverside Research Institute   53
#
#     job_simp  skills  Company Rating Company Name  temp
# ...

# %%
pd.DataFrame(df.iloc[716,])
# Out:
#                                                                  716
# Job Title                  Research Scientist – Security and Privacy
# Salary Estimate                                                93500
# Job Description    ["Returning Candidate? Log back in to the Care...
# Rating                                                           3.6
# Headquarters                                           Arlington, VA
# Size                                                               4
# Founded                                                         1967
# Type of ownership                             Nonprofit Organization
# Industry                                            Federal Agencies
# Sector                                                    Government
# Revenue                                            50 to 100 million
# Competitors                                                     None
# company_txt                             Riverside Research Institute
# ...

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                     131
# Data Engineer                       52
# Senior Data Scientist               34
# Data Analyst                        15
# Senior Data Engineer                14
#                                   ...
# Associate Scientist                  1
# Scientist 2, QC Viral Vector         1
# Data Scientist/ML Engineer           1
# Sr. Data Scientist                   1
# Machine Learning Engineer (NLP)      1
# Name: Job Title, Length: 258, dtype: int64

# %%
df['Revenue'].describe
# Out:
# <bound method NDFrame.describe of 0       50 to 100 million
# 1          2 to 5 billion
# 2      100 to 500 million
# 3             750 million
# 4                       0
#               ...
# 712            10 billion
# 713    100 to 500 million
# 714                     0
# 715       5 to 10 million
# 716     50 to 100 million
# Name: Revenue, Length: 717, dtype: object>

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 m', '2 to 5 b', '100 to 500 m', '750 m', '0',
#        '1 to 2 b', '25 to 50 m', '10 b', '1 to 5 m', '10 to 25 m',
#        '5 to 10 b', '50000', '5 to 10 m'], dtype=object)

# %%
df['Revenue']=df['Revenue'].str.replace('illion','')

# %%
data=df

# %%
df['Revenue'].str.replace(' m','').split(' to ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12004\2303047046.py in <module>
# ----> 1 df['Revenue'].str.replace(' m','').split(' to ')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
def func():
    
    for i in df['Revenue']:
        if 'm' in i:
#             print(True)
            pass
        if '50000' in i:
            print(50000)
        else:
#             print(False)
            pass

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 m', '2 to 5 b', '100 to 500 m', '750 m', '0',
#        '1 to 2 b', '25 to 50 m', '10 b', '1 to 5 m', '10 to 25 m',
#        '5 to 10 b', '50000', '5 to 10 m'], dtype=object)

# %%
func()
# Out:
# 50000
# 50000
# 50000
# 50000

# %%
# Split single column into two columns use apply()
df[['R1', 'R2']] = df["Revenue"].apply(lambda x: pd.Series(str(x).replace(' m','').split(' to ')))
df[['R1', 'R2']] = df["Revenue"].apply(lambda x: pd.Series(str(x).replace(' b','').split(' to ')))
print(df)
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...

# %%
df['Revenue'].unique()
# Out:
# array(['50 to 100 m', '2 to 5 b', '100 to 500 m', '750 m', '0',
#        '1 to 2 b', '25 to 50 m', '10 b', '1 to 5 m', '10 to 25 m',
#        '5 to 10 b', '50000', '5 to 10 m'], dtype=object)

# %%
df['Revenue']=df['Revenue'].replace({'50 to 100 m':75*pow(10,6),'2 to 5 b':3.5*pow(10,9),'100 to 500 m':300*pow(10,6),'750 m':750*pow(10,6),'1 to 2 b':1.5*pow(10,9),'25 to 50 m':75*pow(10,6),'25 to 50 m':75*pow(10,6),'25 to 50 m':75*pow(10,6),'25 to 50 m':75*pow(10,6),'25 to 50 m':75*pow(10,6),'10 b':10*pow(10,9),'1 to 5 m':3*pow(10,6),'10 to 25 m':17.5*pow(10,6),'5 to 10 b':7.5*pow(10,9),'5 to 10 m':7.5*pow(10,6)})

# %%
df['Revenue'].unique()
# Out:
# array([   75000000,  3500000000,   300000000,   750000000,  1500000000,
#        10000000000,     3000000,    17500000,  7500000000,       50000,
#            7500000], dtype=int64)

# %%
df['Revenue']=df['Revenue'].replace({'0':0})

# %%
# converting 0 to median value

# %%
df['Revenue']=df['Revenue'].astype(np.int64)

# %%
np.median(df['Revenue'])
# Out:
# 300000000.0

# %%
df['Revenue']=df['Revenue'].replace({0:np.median(df['Revenue'])})

# %%
df.drop(['R1','R2','temp'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry',
#        'Sector', 'Revenue', 'Competitors', 'company_txt', 'age', 'job_simp',
#        'skills', 'Company Rating', 'Company Name'],
#       dtype='object')

# %%
df.drop(['job_simp'],axis=1,inplace=True)

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                       Data Scientist            72000
# 1                            Healthcare Data Scientist            87500
# 2                                       Data Scientist            85000
# 3                                       Data Scientist            76500
# 4                                       Data Scientist           114500
# ..                                                 ...              ...
# 712           Sr Scientist, Immuno-Oncology - Oncology           102500
# 713                               Senior Data Engineer            73500
# 714  Project Scientist - Auton Lab, Robotics Institute           127500
# 715                               Data Science Manager            93500
# 716          Research Scientist – Security and Privacy            93500
#
#                                        Job Description  Rating  \
# ...
